# %% [markdown]
# Build a Simple LLM Application with LCEL
#
# In this quickstart we'll show you how to build a simple LLM application with LangChain. This application will translate text from English into another language. This is a relatively simple LLM application – it's just a single LLM call plus some prompting. Still, this is a great way to get started with LangChain – a lot of features can be built with just some prompting and an LLM call!
#
# After seeing this video, you'll have a high level overview of:
#
# Using language models
#
# Using PromptTemplates and OutputParsers
#
# Using LangChain Expression Language (LCEL) to chain components together
#
# Debugging and tracing your application using LangSmith
#
# Deploying your application with LangServe

# %%
# !pip install langchain
# Out:
# Requirement already satisfied: langchain in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (1.2.10)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langchain) (1.2.14)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.8 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langchain) (1.0.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.6)
# Requirement already satisfied: packaging>=23.2.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.7 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (1.0.7)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (0.3.5)
# Requirement already satisfied: xxhash>=3.5.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: jsonpointer>=1.9 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.8->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (4.12.1)
# Requirement already satisfied: certifi in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (1.0.9)
# Requirement already satisfied: idna in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.6.3)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
####GROQ LPU: fast ai inference
### Open AI API Key and Open Source models--Llama3, Gemma2, mistral--Groq

import os
from dotenv import load_dotenv
load_dotenv()

import openai
openai.api_key = os.getenv("OPENAI_API_KEY")

groq_api_key = os.getenv("GROQ_API_KEY")

# %%
# !pip install langchain_groq
##library to connect to groq api
# Out:
# Requirement already satisfied: langchain_groq in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (1.1.2)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langchain_groq) (0.37.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.8 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langchain_groq) (1.2.14)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (2.12.5)
# Requirement already satisfied: sniffio in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (4.15.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (0.7.6)
# Requirement already satisfied: packaging>=23.2.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.8->langchain_groq) (0.14.0)
# Requirement already satisfied: idna>=2.8 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain_groq) (3.11)
# Requirement already satisfied: certifi in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.8->langchain_groq) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain_groq) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.8->langchain_groq) (2.6.3)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_openai import ChatOpenAI
from langchain_groq import ChatGroq
model = ChatGroq(model="Gemma2-9b-It", groq_api_key=groq_api_key)
model
# Out:
# ChatGroq(profile={}, client=<groq.resources.chat.completions.Completions object at 0x000001E9A10E3590>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001E9A1235D50>, model_name='Gemma2-9b-It', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
# !pip install langchain_core
# Out:
# Requirement already satisfied: langchain_core in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (1.2.14)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langchain_core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langchain_core) (0.7.6)
# Requirement already satisfied: packaging>=23.2.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langchain_core) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langchain_core) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langchain_core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langchain_core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langchain_core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langchain_core) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain_core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.4.2)
# Requirement already satisfied: anyio in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (4.12.1)
# Requirement already satisfied: certifi in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (1.0.9)
# Requirement already satisfied: idna in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\gen ai\krish naik cource\01. introduction\code2\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (2.6.3)
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
model = ChatGroq(model="Gemma2-9b-It", groq_api_key=groq_api_key)

# %%
model = ChatGroq(model="llama3-8b-8192", groq_api_key=groq_api_key)

# %%
from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage, SystemMessage
import os

model = ChatGroq(
    model="llama-3.1-8b-instant",
    groq_api_key=os.getenv("GROQ_API_KEY")
)

messages = [
    SystemMessage(content="Translate the following from English to French"),
    HumanMessage(content="Hello how are you?")
]

result = model.invoke(messages)

print(result.content)
# Out:
# Bonjour comment allez-vous ?

# %%
from langchain_core.output_parsers import StrOutputParser
parser = StrOutputParser()
parser.invoke(result)
# Out:
# 'Bonjour comment allez-vous ?'

# %%
##using LCEL - chain thr components together
chain = model | parser
chain.invoke(messages)
# Out:
# 'Bonjour, comment allez-vous ?'

# %%
### Prompt Templates
from langchain_core.prompts import ChatPromptTemplate

generic_template = "Trnaslate the following into {language}:"

prompt = ChatPromptTemplate.from_messages(
    [("system", generic_template), ("user", "{text}")]
)

# %%
result = prompt.invoke({"language": "French", "text": "Hello how are you?"})
# Out:
# ChatPromptValue(messages=[SystemMessage(content='Trnaslate the following into French:', additional_kwargs={}, response_metadata={}), HumanMessage(content='Hello how are you?', additional_kwargs={}, response_metadata={})])

# %%
print(result.content)
# Out:
# Bonjour comment allez-vous ?

# %%
###langserve help in creating restapi for our llm
